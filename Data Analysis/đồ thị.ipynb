# %%
import pandas as pd

df1 = pd.DataFrame(
    {
        'length' : [1,2,3,4,5,6,7,8,6],
        'width' : [3,4,1,2,4,5,6,3,2]
    }
)

hist = df1.hist(bins =50)

# %%
import pandas as pd

df1 = pd.DataFrame(
    {
        'length' : [1,2,3,4,5,6,7,8,6],
        'width' : [3,4,1,2,4,5,6,3,2]
    }
)

hist = df1.hist(bins =50)

# %%
import matplotlib.pyplot as plt
import numpy as np

np.set_printoptions(precision=3)

d = np.random.laplace(loc = 15, scale=3, size=500)

d[:5]

n, bins, patches = plt.hist(
    x = d,
    bins= 'auto',
    color= '#0505aa',
    alpha=0.7,
    rwidth=0.85
)

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram chart')
plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
plt.ylim(top=np.ceil(maxfreq/10)*10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 80.0)

# %%
d = np.random.laplace(loc = 15, scale=3, size=500)
print(d)
d[:5]
# Out:
# [14.782 13.559 16.27  14.579 20.667 18.962 14.498 14.972 19.629 12.778
#   8.749 14.51  14.696 15.985 13.031 21.374 15.239 14.848  9.047 17.228
#  16.804 18.602 11.845 19.957 11.683 16.694 10.204 21.337 16.771 15.7
#  15.274 20.706 15.191 19.227 16.368 13.613 17.143 15.563 17.743 14.414
#  12.798 16.182 15.261 16.995 16.934 10.716 13.609 11.794 12.428  7.907
#   1.831 18.684 12.217  0.082  6.863 19.927 19.344 15.963 17.204 17.088
#  14.323  6.182 13.217 16.696 20.762 11.752 15.436 28.907  9.878 15.227
#  14.906 14.56  13.391 12.225 15.008 13.832 12.214 20.23   8.98   6.74
#  17.623 13.849 14.295 12.99  14.384 18.346 16.127 11.338 18.712 14.114
#  10.528 13.795 11.72  11.542 20.778 13.432 12.966 17.122 10.087 10.941
#  15.136 16.923 17.304 14.863 15.165 13.028 15.807 11.707 19.305 12.358
#  13.974 12.591 10.02   6.323 11.965 15.182  9.764 16.054 13.851 15.394
#  19.397 22.133 20.485 13.357 13.525 14.98  25.455 14.814 17.741 15.219
# ...

# %%
import pandas as pd

df = pd.DataFrame(
    [
        [5.1, 3.5, 0],
        [4.9, 3.0, 0],
        [7.0, 3.1, 1],
        [6.4, 3.2, 1],
        [5.9, 3.0, 2]
    ],
    columns= ['length', 'width', 'species']
)

ax1 = df.plot.scatter(
    x = 'length',
    y = 'width',
    c = 'species'
)

# %%
import pandas as pd

d = pd.read_csv("American-height-weight.csv")

df2 = pd.DataFrame(d, columns= ['Height', 'Weight'])

ax2 = df2.plot.scatter(
    x = 'Height',
    y = 'Weight',
)

# %%
# Bar chart
df3 = pd.DataFrame(
    {
        'lab' : ['A', 'B', 'C'],
        'val' : [10, 20, 30]
    }
)

ax3 = df3.plot.bar(
    x = 'lab',
    y = 'val',
    rot = 0
)
